# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# W poniższym przykładzie posłużymy się zestawem danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
df_adv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio']]
y = df_adv['sales']
df_adv.head()
## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
#est = sm.OLS(y, X).fit()
#est.summary()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# # Zad
# Proszę narysować dane za pomoca
# ```python
# sns.pairplot()
# ```

# %% [markdown]
# # Zad
# Proszę wyrysować dane za pomoca
# ```python
# sns.heatmap()
# ```

# %%
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # Zadanie 1 - Konkurs
# Wykonaj model pozwalający przewidzieć zmienną "Sales" na podstawie innych zmiennych.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~ I(newspaper*TV) ', data=df_adv).fit()
print((est.summary2()))
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.379
# Dependent Variable: sales            AIC:                1134.9346
# Date:               2019-06-08 14:36 BIC:                1141.5313
# No. Observations:   200              Log-Likelihood:     -565.47
# Df Model:           1                F-statistic:        122.7
# Df Residuals:       198              Prob (F-statistic): 1.68e-22
# R-squared:          0.383            Scale:              16.892
# ------------------------------------------------------------------
#                     Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept          10.9759   0.4001 27.4304 0.0000 10.1869 11.7650
# I(newspaper * TV)   0.0007   0.0001 11.0766 0.0000  0.0005  0.0008
# ------------------------------------------------------------------
# Omnibus:               13.173       Durbin-Watson:          1.915
# Prob(Omnibus):         0.001        Jarque-Bera (JB):       14.044
# Skew:                  0.571        Prob(JB):               0.001
# Kurtosis:              3.616        Condition No.:          9210
# ==================================================================
# * The condition number is large (9e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels 
statsmodels.__version__
# Out:
# '0.8.0'

# %%
import pandas 
pandas.__version__
# Out:
# '0.23.3'
