# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# /Users/smucha/miniconda3/envs/py3k/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# W poniższym przykładzie posłużymy się zestawem danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
df_adv = pd.read_csv('https://raw.githubusercontent.com/przem85/bootcamp/master/statistics/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio']]
y = df_adv['sales']
# df_adv.head()
## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     5206.
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):          6.73e-172
# Time:                        14:21:18   Log-Likelihood:                -426.71
# No. Observations:                 200   AIC:                             857.4
# Df Residuals:                     198   BIC:                             864.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0548      0.001     42.962      0.000       0.052       0.057
# radio          0.2356      0.008     29.909      0.000       0.220       0.251
# ==============================================================================
# Omnibus:                        6.047   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                8.829
# Skew:                          -0.112   Prob(JB):                       0.0121
# Kurtosis:                       4.005   Cond. No.                         9.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Zad
# Proszę narysować dane za pomoca
# ```python
# sns.pairplot()
# ```

# %%
import seaborn as sns
sns.set_style()
sns.pairplot(df_adv)

# %% [markdown]
# # Zad
# Proszę wyrysować dane za pomoca
# ```python
# sns.heatmap()
# ```

# %%
sns.heatmap(df_adv)

# %% [markdown]
# # Zadanie 1 - Konkurs
# Wykonaj model pozwalający przewidzieć zmienną "Sales" na podstawie innych zmiennych.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~ I(TV ** 0.0012)*I(TV - TV.mean())', data=df_adv).fit()
print((est.summary2()))
# Out:
#                              Results: Ordinary least squares
# ==========================================================================================
# Model:                      OLS                      Adj. R-squared:             0.622
# Dependent Variable:         sales                    AIC:                        1037.7388
# Date:                       2019-11-08 15:10         BIC:                        1050.9321
# No. Observations:           200                      Log-Likelihood:             -514.87
# Df Model:                   3                        F-statistic:                110.2
# Df Residuals:               196                      Prob (F-statistic):         7.79e-42
# R-squared:                  0.628                    Scale:                      10.288
# ------------------------------------------------------------------------------------------
#                                     Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ------------------------------------------------------------------------------------------
# Intercept                         -2626.9464 3005.4609 -0.8741 0.3832 -8554.1397 3300.2469
# I(TV ** 0.0012)                    2625.5393 2987.3269  0.8789 0.3805 -3265.8912 8516.9698
# I(TV - TV.mean())                    -7.2674   14.7803 -0.4917 0.6235   -36.4162   21.8815
# I(TV ** 0.0012):I(TV - TV.mean())     7.2445   14.6674  0.4939 0.6219   -21.6816   36.1706
# ------------------------------------------------------------------------------------------
# Omnibus:                       0.132               Durbin-Watson:                  2.014
# Prob(Omnibus):                 0.936               Jarque-Bera (JB):               0.279
# Skew:                          0.008               Prob(JB):                       0.870
# Kurtosis:                      2.818               Condition No.:                  2268676
# ==========================================================================================
# * The condition number is large (2e+06). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
import statsmodels 
statsmodels.__version__
# Out:
# '0.9.0'

# %%
import pandas 
pandas.__version__
# Out:
# '0.23.4'

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~ I(newspaper)*I(TV)*I(radio)*I(TV ** 1.25)*I(radio**1.5)*I(newspaper**0.5)*I(TV - TV.mean())', data=df_adv).fit()
print((est.summary2()))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-d9b6cd226c50> in <module>
#       2
#       3 # formula: response ~ predictor + predictor
# ----> 4 est = smf.ols(formula='sales ~ I(newspaper)*I(TV)*I(radio)*I(TV ** 1.25)*I(radio**1.5)*I(newspaper**0.5)*I(TV - TV.mean())', data=df_adv).fit()
#       5 print((est.summary2()))
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/desc.py in from_formula(cls, tree_or_string)
#     162             tree = tree_or_string
#     163         else:
# --> 164             tree = parse_formula(tree_or_string)
#     165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/parse_formula.py in parse_formula(code, extra_operators)
#     146     tree = infix_parse(_tokenize_formula(code, operator_strings),
#     147                        operators,
# --> 148                        _atomic_token_types)
#     149     if not isinstance(tree, ParseNode) or tree.type != "~":
#     150         tree = ParseNode("~", None, [tree], tree.origin)
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/infix_parser.py in infix_parse(tokens, operators, atomic_types, trace)
#     208
#     209     want_noun = True
# --> 210     for token in token_source:
#     211         if c.trace:
#     212             print("Reading next token (want_noun=%r)" % (want_noun,))
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/parse_formula.py in _tokenize_formula(code, operator_strings)
#      92         else:
#      93             it.push_back((pytype, token_string, origin))
# ---> 94             yield _read_python_expr(it, end_tokens)
#      95
#      96 def test__tokenize_formula():
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/parse_formula.py in _read_python_expr(it, end_tokens)
#      42     origins = []
#      43     bracket_level = 0
# ---> 44     for pytype, token_string, origin in it:
#      45         assert bracket_level >= 0
#      46         if bracket_level == 0 and token_string in end_tokens:
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/util.py in next(self)
#     330         else:
#     331             # May raise StopIteration
# --> 332             return six.advance_iterator(self._it)
#     333     __next__ = next
#     334
#
# ~/miniconda3/envs/py3k/lib/python3.6/site-packages/patsy/tokens.py in python_tokenize(code)
#      33                 break
#      34             origin = Origin(code, start, end)
# ---> 35             assert pytype not in (tokenize.NL, tokenize.NEWLINE)
#      36             if pytype == tokenize.ERRORTOKEN:
#      37                 raise PatsyError("error tokenizing input "
#
# AssertionError:
